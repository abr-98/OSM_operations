# %%
import osmnx as ox
city = ox.gdf_from_place('Berkeley, California')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f43aabeada0>)

# %%
places = ox.gdf_from_places(['Botswana', 'Zambia', 'Zimbabwe'])
places = ox.project_gdf(places)
ox.save_gdf_shapefile(places)
ox.plot_shape(ox.project_gdf(places))
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f43aaac2c50>)

# %%
G = ox.graph_from_bbox(37.79, 37.78, -122.41, -122.43, network_type='drive')
G_projected = ox.project_graph(G)
ox.plot_graph(G_projected)
# Out:
# (<Figure size 687.674x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f43a9924588>)

# %%
G = ox.graph_from_point((37.79, -122.41), distance=750, network_type='all')
ox.plot_graph(G)
# Out:
# (<Figure size 540.165x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f439f652780>)

# %%
G = ox.graph_from_address('350 5th Ave, New York, New York', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 568.567x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f439f7a1e48>)

# %%
import osmnx as ox
import pandas as pd
import numpy as np

df=pd.read_csv('6mar.csv')

st_lat=df['Start_Lat'].values
st_lng=df['Start_Lng'].values
end_lat=df['End_Lat'].values
end_lng=df['End_Lng'].values

print("a")

st_latl=st_lat.tolist()
st_lngl=st_lng.tolist()

print("b")

end_latl=end_lat.tolist()
end_lngl=end_lng.tolist()

print("c")

l=len(st_latl)

print("d")
print(st_latl[0])
print(st_lngl[0])
print(end_latl[0])
print(end_lngl[0])
G = ox.graph_from_bbox(st_latl[2], end_latl[2], st_lngl[2],end_lngl[2], network_type='drive')
G_projected = ox.project_graph(G)
ox.plot_graph(G_projected)
# Out:
# a
# b
# c
# d
# 23.54599549
# 87.29266503
# 23.54436063
# 87.29155364
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-31-5c49e05e3931> in <module>
#      29 print(end_latl[0])
#      30 print(end_lngl[0])
# ---> 31 G = ox.graph_from_bbox(st_latl[2], end_latl[2], st_lngl[2],end_lngl[2], network_type='drive')
#      32 G_projected = ox.project_graph(G)
#      33 ox.plot_graph(G_projected)
#
# ~/.local/lib/python3.6/site-packages/osmnx/core.py in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter)
#    1491         # truncate graph by desired bbox to return the graph within the bbox
#    1492         # caller wants
# -> 1493         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1494
#    1495         # count how many street segments in buffered graph emanate from each
#
# ~/.local/lib/python3.6/site-packages/osmnx/core.py in truncate_graph_bbox(G, north, south, east, west, truncate_by_edge, retain_all)
#    1003     if not retain_all:
#    1004         G = remove_isolated_nodes(G)
# -> 1005         G = get_largest_component(G)
#    1006
#    1007     return G
#
# ~/.local/lib/python3.6/site-packages/osmnx/utils.py in get_largest_component(G, strongly)
#     344     else:
#     345         # if the graph is not connected retain only the largest weakly connected component
# --> 346         if not nx.is_weakly_connected(G):
#     347
#     348             # get all the weakly connected components in graph then identify the largest
#
# <decorator-gen-324> in is_weakly_connected(G)
#
# ~/.local/lib/python3.6/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
# ---> 82             return not_implement_for_func(*args, **kwargs)
#      83     return _not_implemented_for
#      84
#
# ~/.local/lib/python3.6/site-packages/networkx/algorithms/components/weakly_connected.py in is_weakly_connected(G)
#     165     if len(G) == 0:
#     166         raise nx.NetworkXPointlessConcept(
# --> 167             """Connectivity is undefined for the null graph.""")
#     168
#     169     return len(list(weakly_connected_components(G))[0]) == len(G)
#
# NetworkXPointlessConcept: Connectivity is undefined for the null graph.

# %%
import osmnx as ox
G = ox.graph_from_place('Modena, Italy')
ox.plot_graph(G)
# Out:
# (<Figure size 599.212x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f439c2f4668>)

# %%
import osmnx as ox
G = ox.graph_from_place('Kolkata, India')
ox.plot_graph(G)

# %%
from shapely.geometry import Point, Polygon
import geopandas as gpd
import pandas as pd
df = pd.read_csv('6mar.csv')
# the columns of the DataFrame
df.columns
([u'ID', u'X', u'Y'], dtype='object')
df['geometry'] = df.apply(lambda row: Point(row.X, row.Y), axis=1)
df  = gpd.GeoDataFrame(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6827c30a2e53> in <module>
#       5 # the columns of the DataFrame
#       6 df.columns
# ----> 7 Index([u'ID', u'X', u'Y'], dtype='object')
#       8 df['geometry'] = df.apply(lambda row: Point(row.X, row.Y), axis=1)
#       9 df  = gpd.GeoDataFrame(df)
#
# NameError: name 'Index' is not defined
